# %% [markdown]
# # INFO 159/259
# #<center> Homework 5: Information Extraction </center>
#
# <center> Due: April 6, 2026 @ 11:59pm </center>

# %% [markdown]
# In this assignment, we'll examine how one could use **bootstrapping** to extract relations between entities from a dataset.
#
# Imagine you have been appointed to manage a large and ecologically diverse preserve. Here, the wifi is shaky, and the cell service is non-existent. It'll be a nice respite from trudging through endless midterms at Berkeley.
#
# However, this morning, a group of long-tailed macques ambushed you and stole your paper records detailing a taxonomy of the animals. You're left in a troubling situation, as without this taxonomy, it's tough to know which animals are which types and properly care for them. What are giraffes? Cephalopods? You're not too sure.
#
# The zoologists are on vacation, and have only left behind a collection of long-form notes describing the animals. Your only hope is to use relation extraction methods from INFO 159/259 to restructure these notes and get a head start on rebuilding the stolen taxonomy.

# %% [markdown]
# Your knowledge of animals is pretty flimsy. Luckily, you recall from [Jurafsky & Martin Chapter 20](https://web.stanford.edu/~jurafsky/slp3/20.pdf) the following algorithm for bootstrapping:
#
# ```
# function BOOTSTRAP(Relation_R) returns new_relation_tuples
#   tuples ← Gather a set of seed tuples that have relation R
#   iterate
#     sentences ← find sentences that contain entities in tuples
#     patterns ← generalize the context between and around entities in sentences
#     new_pairs ← use patterns to identify more tuples
#     new_pairs ← new_pairs with high confidence
#     tuples ← tuples + new_pairs
#   return tuples
# ```

# %% [markdown]
# We'll demonstrate the affordances and caveats of this algorithm by walking through one iteration. We'll gather phrases that are suggestive of *is-a* relations between animals and their types, and recover new hyponym-hypernym pairs to save the day.

# %% [markdown]
# > **Only** modify text or code in between `### BEGIN SOLUTION` and `### END SOLUTION` lines. There are also some "Consider" questions; answer these to earn full credit.

# %%
# !pip install dafsa
# Out:
# Requirement already satisfied: dafsa in /usr/local/lib/python3.12/dist-packages (1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from dafsa) (3.6.1)

# %%
import itertools
from collections import defaultdict, Counter
from tqdm import tqdm
import networkx as nx
from dafsa import DAFSA
import re
import random

# %% [markdown]
# # Introduction

# %% [markdown]
# ### **Learning Objectives**
# In this homework, you will:
# - mine for patterns through transforming pre-processed text into tuples
# - understand the process of Relation Extraction and how semantic drift may be accounted for using bootstrapping

# %% [markdown]
# You think it's a bit wild (pun intended) that the records at this animal preserve are still all on paper. You digitize the zoologists' handwritten notes, and preprocess your dataset to include token indices of nouns that refer to animals in your nature preserve (ANIMAL), and token indices of other nouns detected by a spaCy POS tagger (NOUN).
#
# Download this digitized file of pre-tagged notes by running the following cell.

# %%
# !wget https://github.com/dbamman/nlp-course/raw/refs/heads/main/HW/data/tagged_sentences.txt -O tagged_sentences.txt
# Out:
# --2026-04-05 23:36:19--  https://github.com/dbamman/nlp-course/raw/refs/heads/main/HW/data/tagged_sentences.txt
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dbamman/nlp-course/refs/heads/main/HW/data/tagged_sentences.txt [following]
# --2026-04-05 23:36:20--  https://raw.githubusercontent.com/dbamman/nlp-course/refs/heads/main/HW/data/tagged_sentences.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6290129 (6.0M) [text/plain]
# Saving to: ‘tagged_sentences.txt’
#
# tagged_sentences.tx 100%[===================>]   6.00M  --.-KB/s    in 0.05s
#
# 2026-04-05 23:36:21 (111 MB/s) - ‘tagged_sentences.txt’ saved [6290129/6290129]

# %% [markdown]
# In this tab-delimited file,
# 1. the first column is the lemmatized name of an animal,
# 2. the second column is a sentence, and
# 3. the third column is a tokenized, lemmatized form of that sentence.
#
# The remaining columns are indices of animals and non-target-animal nouns in the sentence.

# %%
with open('tagged_sentences.txt', 'r') as infile:
  for line in infile:
    print(line.strip().split('\t')) # view each column
    break
# Out:
# ['horse', 'The horse is a domesticated, one-toed, hoofed mammal.', 'the horse be a domesticate , one - toed , hoofed mammal .', 'ANIMAL 1', 'NOUN 11']

# %% [markdown]
# Here are all animal *is-a* relations that you can remember right now. This is your set of seed tuples for bootstrapping.

# %%
seed_tuples = [('kangaroo', 'marsupial'), ('kangaroo', 'mammal'), ('horse', 'mammal'), ('toucan', 'bird'),
                ('crocodile', 'reptile'), ('ant', 'anthropod'), ('dinosaur', 'reptile'), ('hawk', 'bird'),
                ('eagle', 'bird'), ('lark', 'bird'), ('toad', 'amphibian'), ('frog', 'amphibian'), ('ibis', 'bird'),
                ('oyster', 'shellfish'), ('pigeon', 'bird'), ('shark', 'fish'), ('hummingbird', 'bird'),
                ('jellyfish', 'cnidarian'), ('octopus', 'cephalopod'), ('anteater', 'xenarthan'), ('moose', 'mammal'),
                ('dragonfly', 'insect'), ('camel', 'mammal'), ('beetle', 'insect'), ('kinkajou', 'mammal'), ('alpaca', 'mammal')]

# %% [markdown]
# # Deliverables

# %% [markdown]
# ## Mining for patterns
#
# Let's find sentences in the zoologists' notes that contain our seed set of `(ANIMAL, NOUN)` tuples, and extract the context around them.
#
# Each phrasal pattern has three key parts:
# - the middle context between one 'ANIMAL' and one 'NOUN'
# - a left context of at most $n$ space-separated tokens to the left
# - a right context of at most $m$ space-separated tokens to the right.

# %% [markdown]
# For example, here are some phrasal patterns with $n=2$ and $m=2$:
#
# - `the ANIMAL be a NOUN .` ← "The giraffe is a mammal.",
# - `as a NOUN , a ANIMAL have fur` ← "As a mammal, a giraffe has fur.".

# %% [markdown]
# ### To-Do
#
# Implement the following function that takes in token indices of an `(ANIMAL, NOUN)` pair and a preprocessed sentence from your zoologists' notes. The output is a phrasal pattern.
#
# For example, given the preprocessed (lemmatized & tokenized) sentence
#
# ```
# ['tall', 'and', 'long', '-', 'neck', ',', 'the', 'giraffe', 'be', 'a', 'mammal', ',', 'and', 'it', 'eat', 'leaf', 'from', 'high', 'branch', 'of', 'tree', '.']
# ```
#
# and indices of `('giraffe', 'mammal')` as `(7, 10)`, and $n=2$ and $m=2$, your function should output
#
# ```
# , the ANIMAL be a NOUN , and
# ```
#
# With $n=5$ and $m=5$, your function should instead output
#
# ```
# long - neck , the ANIMAL be a NOUN , and it eat leaf
# ```

# %%
def transform_text_into_pattern(animal_noun, tokenized_sentence, n, m):
  '''
  @inputs:
  - animal_noun: a tuple of (ANIMAL, NOUN) indices
    For example, in the sentence "The horse is a domesticated, one-toed, hoofed mammal.",
    animal_noun == (1, 11),
    where token index 1 is "horse" and token index 11 is "mammal".
  - tokenized_sentence: a lemmatized, tokenized sentence, represented as a list of tokens
  - n: an integer indicating the size, or number of tokens, of the left context window
  - m: an integer indicating the size, or number of tokens, of the right content window

  @outputs:
  - phrase: a string containing left, middle, and right context around ANIMAL and NOUN
  '''
  phrase = ''

  ### BEGIN SOLUTION
  num_tokens = len(tokenized_sentence)
  start_ix = max(min(animal_noun[0], animal_noun[1])-n, 0)
  end_ix = min(max(animal_noun[0], animal_noun[1])+m, num_tokens-1)
  tokenized_sentence[animal_noun[0]] = "ANIMAL"
  tokenized_sentence[animal_noun[1]] = "NOUN"
  phrase = (" ").join(tokenized_sentence[start_ix:end_ix+1])
  ### END SOLUTION
  return phrase.strip()

# %% [markdown]
# Check that your function works as expected by running the following cell.

# %%
phrase = transform_text_into_pattern((1, 4),
      ['the', 'giraffe', 'be', 'a', 'mammal', '.'], 5, 5)
assert(phrase == 'the ANIMAL be a NOUN .')

phrase = transform_text_into_pattern((7, 10),
      ['tall', 'and', 'long', '-', 'neck', ',', 'the', 'giraffe', 'be', 'a',
       'mammal', ',', 'and', 'it', 'eat', 'leaf', 'from', 'high',
       'branch', 'of', 'tree', '.'], 5, 5)
assert(phrase == 'long - neck , the ANIMAL be a NOUN , and it eat leaf')

phrase = transform_text_into_pattern((7, 10),
      ['tall', 'and', 'long', '-', 'neck', ',', 'the', 'giraffe', 'be', 'a',
       'mammal', ',', 'and', 'it', 'eat', 'leaf', 'from', 'high',
       'branch', 'of', 'tree', '.'], 2, 2)
assert(phrase == ', the ANIMAL be a NOUN , and')

phrase = transform_text_into_pattern((5, 2),
      ['as', 'a', 'mammal', ',', 'a', 'giraffe', 'have', 'fur'], 5, 5)
assert(phrase == 'as a NOUN , a ANIMAL have fur')

# %% [markdown]
# Now, we call your function to extract phrasal patterns based on the seed set of tuples. To keep things tidy, we restrict the middle context to be $\leq 10$ tokens long.

# %%
def parse_input_line(line):
  contents = line.strip().split('\t')
  animal = contents[0]
  sentence = contents[1]
  sentence_toks = contents[2].split(' ')

  # get animal and noun indices
  animal_idx = []
  noun_idx = []
  for i in range(3, len(contents)):
    if contents[i].startswith('ANIMAL'):
      animal_idx.append(int(contents[i].split()[-1]))
    elif contents[i].startswith('NOUN'):
      noun_idx.append(int(contents[i].split()[-1]))
  return animal, sentence, sentence_toks, animal_idx, noun_idx

def extract_phrasal_patterns(seed_tuples):
  '''
  @inputs:
  - seed_tuples: a set of seed tuples of (ANIMAL, NOUN)

  @outputs:
  - phrasal_patterns: a dictionary of patterns to their original sentences
  '''
  phrasal_patterns = defaultdict(list)

  with open('tagged_sentences.txt', 'r') as infile:
    for line in tqdm(infile, total=19587):
      animal, sentence, sentence_toks, animal_idx, noun_idx = parse_input_line(line)

      # get phrasal contexts of animal and noun pairs
      for pair in itertools.product(animal_idx, noun_idx):
        if (sentence_toks[pair[0]], sentence_toks[pair[1]]) in seed_tuples:
          if abs(pair[0] - pair[1]) <= 10:
            # calls the function that you wrote
            phrase = transform_text_into_pattern(pair, sentence_toks, 5, 5)
            phrasal_patterns[phrase].append(sentence)

  return phrasal_patterns

# %%
phrasal_patterns = extract_phrasal_patterns(seed_tuples)
# Out:
# 100%|██████████| 19587/19587 [00:00<00:00, 103229.86it/s]

# %%
pattern = 'the ANIMAL be a domesticate , one - toed , hoofed NOUN .'
print(phrasal_patterns[pattern])
# this cell should print out "['The horse is a domesticated, one-toed, hoofed mammal.']"
# Out:
# ['The horse is a domesticated, one-toed, hoofed mammal.']

# %% [markdown]
# It is good to *generalize* the context around target entities, to account for irrelevant contextual variations. There are many ways one could approach this. Here, we'll replace infrequent parts of contexts with a wildcard `*`.

# %% [markdown]
# We implement pattern generalization for you. To do so, we construct a directed acyclic word graph by looping through all of the phrasal patterns our seed tuples found. Each edge of this graph represents one word (unlike [the example figure on Wikipedia](https://en.wikipedia.org/wiki/Deterministic_acyclic_finite_state_automaton), where each edge is a letter/character). Each path starting at the root of this graph is a phrasal pattern, and edge weights are incremented based on how often they are traversed across all patterns. If an edge appears less than 3 times, it is replaced with a `*`.  Our implementation is heavily inspired by Section 3.3 of [this paper](https://arxiv.org/abs/1804.02525).
#
# For example, the sentences "_**Giraffes** are large African hoofed **mammals** who eats leaves._" and "_**Giraffes** are tall **mammals** living in grassy, open woodlands._" could be both represented by the pattern `ANIMAL be * NOUN *`.

# %%
def build_graph(phrasal_patterns):
    """
    Builds a directed word graph from a set of phrasal patterns.
    Each word is weighted by its count in the graph.

    @input:

    @output:
    - a networkx graph
    """
    words = []
    for pattern in phrasal_patterns:
        words.append(pattern.split(' '))
    d = DAFSA(words) # creates directed acyclic word graphs

    # convert d into a networkx graph that is directed and has parallel edges
    graph = nx.MultiDiGraph()
    for node_id, node in d.nodes.items():
      graph.add_node(node_id)
      graph.nodes[node_id]["final"] = node.final

    for left in d.nodes.values():
        for label, right in left.edges.items():
            l_id = left.node_id
            r_id = right.node.node_id
            graph.add_edge(l_id, r_id, weight=right.weight, label=label)

    return graph

def clean_up_patterns(all_patterns):
  clean_patterns = set()
  for pattern in all_patterns:
    pattern_string = ' '.join(pattern)
    # reduce repeated * into a single *
    pattern_string = re.sub(r'(\*\s?)+', '* ', pattern_string)
    # constraint: some middle context must exist
    if 'ANIMAL * NOUN' in pattern_string or 'NOUN * ANIMAL' in pattern_string:
      continue
    clean_patterns.add(pattern_string.strip())
  clean_patterns = list(clean_patterns)
  return clean_patterns

def get_generalized_paths(graph):
  '''
  @inputs:
  - a networkx graph

  @outputs:
  - generalized phrasal patterns, as strings
  '''
  final_nodes = []
  for node in graph.nodes(data=True):
    if node[1]['final']:
      final_nodes.append(node[0])
  weight_threshold = 3 # number of times a transition/edge must exist for us to not wildcard it
  do_not_wildcard = ['ANIMAL', 'NOUN'] # tokens that shouldn't be replaced with a wildcard

  clustered_patterns = []
  for end in final_nodes:
    paths = nx.all_simple_edge_paths(graph, 0, end)
    for path in paths:
      this_path = []
      for edge in path:
          src = edge[0]
          dst = edge[1]
          edge_data = graph.get_edge_data(edge[0], edge[1])[edge[2]]
          if edge_data['label'] not in do_not_wildcard and \
              edge_data['weight'] < weight_threshold:
            this_path.append('*')
          else:
            this_path.append(edge_data['label'])
      clustered_patterns.append(this_path)

  clustered_patterns = clean_up_patterns(clustered_patterns)
  clustered_patterns = sorted(clustered_patterns)
  return clustered_patterns

# %%
graph = build_graph(phrasal_patterns)
clustered_patterns = get_generalized_paths(graph)

# %%
clustered_patterns
# Out:
# ['ANIMAL , like * NOUN *',
#  'ANIMAL be * NOUN *',
#  'ANIMAL be * NOUN * .',
#  'ANIMAL be * NOUN * specie',
#  'ANIMAL be NOUN *',
#  'ANIMAL be NOUN * .',
#  'ANIMAL be NOUN * and',
#  'ANIMAL be the * NOUN *',
#  'ANIMAL be the * NOUN * specie',
#  'ANIMAL be the * NOUN .',
#  'like most NOUN , * ANIMAL *',
#  'like most NOUN , ANIMAL * and',
#  'like most NOUN , ANIMAL * the',
#  'like other NOUN , * ANIMAL *',
#  'like other NOUN , ANIMAL *',
#  'like other NOUN , ANIMAL * ,',
#  'like other NOUN , ANIMAL * as',
#  'the ANIMAL be a * NOUN *',
#  'the ANIMAL be a * NOUN .',
#  'unlike other NOUN , * ANIMAL * and',
#  'unlike other NOUN , ANIMAL *',
#  'unlike other NOUN , ANIMAL * be']

# %% [markdown]
# As a sanity check for your implementation, the above cell should output patterns containing n-grams such as "like other NOUN", "like most NOUN", "ANIMAL be", and "unlike other NOUN".
#
# You may notice that some of these patterns are subsets of others. The extent to which we rely on `*` to be a catch-all for the context around ANIMAL and potential NOUNs affects precision, as we'll soon see.

# %% [markdown]
# ## Identify more animal-type tuples
#
# Now, let's use these patterns to find more potential *is-a* relations for the animals in our preserve.

# %% [markdown]
# ### To-Do
#
# Your task is to write a function that takes in a candidate phrase containing ANIMAL and NOUN, and checks whether it matches with a pattern we mined above. Hint: use the regex package `re`.

# %%
def is_match(cand_phrase, pattern):
  '''
  @input:
  - cand_phrase: a candidate phrase containing ANIMAL and NOUN, e.g. "like other NOUN , the ANIMAL eat hay ."
  - pattern: a generalized pattern, e.g. "like other NOUN , * ANIMAL *"

  @output:
  - a boolean of True or False
  '''
  ### BEGIN SOLUTION
  regex_pattern = pattern.replace("*", ".*")
  flag = re.match(regex_pattern, cand_phrase)
  if(flag):
    return True
  else:
    return False
  ### END SOLUTION

# %% [markdown]
# Test out your implementation by running the following cell.

# %%
output = is_match("like other NOUN , the ANIMAL eat hay .", "like other NOUN , * ANIMAL *")
assert output == True

output = is_match("like other NOUN , ANIMAL eat hay .", "like other NOUN , * ANIMAL *")
assert output == False

output = is_match("like other NOUN , ANIMAL eat hay .", "like other NOUN , ANIMAL *")
assert output == True

output = is_match("ANIMAL be a domesticate , one - toed , hoofed NOUN .", "ANIMAL be * NOUN *")
assert output == True

# %%
def get_candidates():
  '''
  @outputs:
  - candidates: a list of (phrase, animal, noun), e.g. ('the ANIMAL be a domesticate , one - toed , hoofed NOUN .', 'horse', 'mammal')
  '''
  candidates = []
  with open('tagged_sentences.txt', 'r') as infile:
    for line in tqdm(infile, total=19587):
      animal, sentence, sentence_toks, animal_idx, noun_idx = parse_input_line(line)

      # get phrasal contexts of animal and noun pairs
      for pair in itertools.product(animal_idx, noun_idx):
        if abs(pair[0] - pair[1]) <= 10:
          # calls the function that you wrote
          phrase = transform_text_into_pattern(pair, sentence_toks, 5, 5)
          candidates.append((phrase, sentence_toks[pair[0]], sentence_toks[pair[1]]))
  return candidates

def filter_for_matches(candidates, clustered_patterns):
  matches = defaultdict(list)
  for cand in tqdm(candidates):
    for pattern in clustered_patterns:
      if is_match(cand[0], pattern):
        matches[pattern].append(cand)
  return matches

# %%
candidates = get_candidates()
matches = filter_for_matches(candidates, clustered_patterns)
# Out:
# 100%|██████████| 19587/19587 [00:00<00:00, 67730.82it/s]
# 100%|██████████| 63573/63573 [00:00<00:00, 64636.12it/s]

# %% [markdown]
# ### To-Do
#
# You remember from [Jurafsky & Martin Ch. 20](https://web.stanford.edu/~jurafsky/slp3/20.pdf), page 8 that
# > Bootstrapping systems also assign confidence values to new tuples to avoid semantic drift. In semantic drift, an erroneous pattern leads to the introduction of erroneous tuples, which, in turn, lead to the creation of problematic patterns and the meaning of the extracted relations ‘drifts’.
#
# > Confidence values for patterns are based on balancing two factors: the pattern’s performance with respect to the current set of tuples and the pattern’s productivity in terms of the number of matches it produces in the document collection.

# %% [markdown]
# With the above in mind, write the following function, `hits_and_finds()`, which returns the following:
# - `num_hits`: the number of unique (ANIMAL, NOUN) tuples in our seed set (`seed_tuples`) that a pattern $p$ matches while looking in our dataset.
# - `num_finds`: the total number of unique (ANIMAL, NOUN) tuples that $p$ finds in our dataset.

# %%
def hits_and_finds(matches, p, seed_tuples):
  '''
  @inputs:
  - matches: a dictionary of the format {generalized pattern: [list of tuples (preprocessed sentence, animal, noun) ] }
  - p: a generalized pattern
  - seed_tuples: a list of seed tuples of the format (animal, noun)

  @outputs:
  - num_hits: an int, or the number of unique seed animal-type tuples found by p
  - num_finds: an int, or the total number of unique animal-type tuples found by p
  '''
  assert p in matches

  pred_tuples = list()
  ### BEGIN SOLUTION
  for pattern in matches:
    for term in matches[pattern]:
      sentence = term[0]
      animal = term[1]
      noun = term[2]
      
      if(is_match(sentence, p)):
        pred_tuples.append((animal, noun))
  
  hit_arr = [x for x in pred_tuples if x in seed_tuples]

  num_hits = len(hit_arr)
  num_finds = len(pred_tuples)
  
  ### END SOLUTION

  return num_hits, num_finds

# %%
matches_toy = {
    'the ANIMAL be a * NOUN *' : [
              ('the ANIMAL be a domesticate , one - toed , hoofed NOUN .',
               'horse',
               'mammal'),
              ('the ANIMAL be a medium - sized NOUN species that be often slightly',
               'mallard',
               'waterfowl'),
              ('the ANIMAL be a social NOUN , form pack of two',
               'meerkat',
               'mammal'),
              ('the ANIMAL be a NOUN .',
               'horse',
               'mammal'),
              ]
}
p_toy = 'the ANIMAL be a * NOUN *'
seed_tuples_toy = [('horse', 'mammal'), ('mallard', 'waterfowl'), ('toucan', 'bird')]

num_hits, num_finds = hits_and_finds(matches_toy, p_toy, seed_tuples_toy)
assert num_hits == 2 # because we hit ('horse', 'mammal') and ('mallard', 'waterfowl')
assert num_finds == 3 # because we find ('horse', 'mammal'), ('mallard', 'waterfowl'), and ('meerkat', 'mammal')

# %% [markdown]
# Let's inspect phrasal patterns and the `(ANIMAL, NOUN)` tuples they surface. For each pattern, we'll give examples of both hits and *new* finds.

# %%
def show_results(matches, seed_tuples):
  '''
  Prints candidate animal-type tuples and the patterns
  that identified them.
  '''
  for pattern in sorted(matches.keys()):
    num_hits, num_finds = hits_and_finds(matches, pattern, seed_tuples)
    hits = []
    new_finds = []
    for tup in matches[pattern]:
      animal_type = (tup[1], tup[2])
      if animal_type in seed_tuples:
        hits.append(tup)
      else:
        new_finds.append(tup)
    if len(new_finds) > 20:
      new_finds = random.sample(new_finds, 20)

    random.seed(0)
    print("Pattern:", pattern)
    print("# of hits: ", num_hits)
    print("Hits:")
    for tup in hits:
      print('\t', tup[1], 'is a', tup[2], '←', tup[0])
    print("# of new finds: ", num_finds - num_hits)
    print("Examples of new finds:")
    if len(new_finds) == 0:
      print("\tNone")
    for tup in new_finds:
      print('\t', tup[1], 'is a', tup[2], '←', tup[0])
    print('\n---------------------------------\n')

# %% [markdown]
# Scroll through the output of the following cell.

# %%
show_results(matches, seed_tuples)
# Out:
# Pattern: *
# # of hits:  0
# Hits:
# # of new finds:  102998
# Examples of new finds:
# 	 ANIMAL is a NOUN ← NOUN - build ANIMAL have poor NOUN , but be extremely sensitive to NOUN .
# 	 ANIMAL is a NOUN ← NOUN ANIMAL , and NOUN ANIMAL
# 	 ANIMAL is a NOUN ← NOUN NOUN , overgrazing by ANIMAL have
# 	 ANIMAL is a NOUN ← ANIMAL that respire use a NOUN belong to the group Pulmonata
# 	 ANIMAL is a NOUN ← all ANIMAL NOUN go through several instar ,
# 	 ANIMAL is a NOUN ← however , unlike many other ANIMAL NOUN parasite , they have pollen
# 	 ANIMAL is a NOUN ← NOUN as NOUN , the ANIMAL undergo extensive NOUN before be place with disabled NOUN .
# 	 ANIMAL is a NOUN ← for fertilize algae
# 	 ANIMAL is a NOUN ← there be strong NOUN that ANIMAL ' coloration be
# 	 ANIMAL is a NOUN ← NOUN " , later " ANIMAL NOUN " , for its NOUN to a bear .
# 	 ANIMAL is a NOUN ← have be exhaust , the ANIMAL emit an anti - aggregation NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL evolve from a NOUN within the stinging wasp ,
# 	 ANIMAL is a NOUN ← the NOUN ANIMAL be one of the most accessible NOUN for early NOUN , because it could be
# 	 ANIMAL is a NOUN ← NOUN wave of an approach ANIMAL
# 	 ANIMAL is a NOUN ← NOUN can be feel by ANIMAL with the NOUN of filoplume — hairlike feather
# 	 ANIMAL is a NOUN ← China and
# 	 ANIMAL is a NOUN ← the ANIMAL , also spell NOUN and sometimes call the common
# 	 ANIMAL is a NOUN ← to the removal
# 	 ANIMAL is a NOUN ← this usually occur when a ANIMAL accidentally rouse the NOUN .
# 	 ANIMAL is a NOUN ← they vulnerable to NOUN , ANIMAL be highly attuned to NOUN source .
#
# ---------------------------------
#
# Pattern: * and
# # of hits:  0
# Hits:
# # of new finds:  39469
# Examples of new finds:
# 	 ANIMAL is a NOUN ← of NOUN ANIMAL and NOUN ANIMAL ,
# 	 ANIMAL is a NOUN ← semi - arid NOUN , ANIMAL spend more than NOUN of each NOUN forage and feed , often
# 	 ANIMAL is a NOUN ← ANIMAL spread NOUN through their NOUN and be often carrier of
# 	 ANIMAL is a NOUN ← the ANIMAL breed from NOUN into spring and have a
# 	 ANIMAL is a NOUN ← vary : the southern royal ANIMAL be almost completely white except for the NOUN and trail edge of the
# 	 ANIMAL is a NOUN ← NOUN than NOUN , and ANIMAL in Russia appear to limit stray NOUN NOUN .
# 	 ANIMAL is a NOUN ← whether NOUN apply to all ANIMAL or all sentient NOUN , and far if a
# 	 ANIMAL is a NOUN ← the giant ANIMAL 's NOUN beat as few as 12 NOUN per second , and the
# 	 ANIMAL is a NOUN ← latrine NOUN exhibit by some ANIMAL may help improve NOUN NOUN and facilitate NOUN NOUN .
# 	 ANIMAL is a NOUN ← / NOUN of NOUN in ANIMAL NOUN and the NOUN NOUN associate with the different NOUN .
# 	 ANIMAL is a NOUN ← the NOUN of a ANIMAL be unique among NOUN and serve to protect the NOUN and provide shelter from the
# 	 ANIMAL is a NOUN ← ANIMAL have appear in NOUN and folklore , through all
# 	 ANIMAL is a NOUN ← some ANIMAL NOUN have develop large and thick
# 	 ANIMAL is a NOUN ← NOUN of a few ANIMAL eat harmful NOUN , and a few be
# 	 ANIMAL is a NOUN ← the NOUN and allow the ANIMAL to detach its NOUN before the next step .
# 	 ANIMAL is a NOUN ← call NOUN , young male ANIMAL be NOUN or bullock , and castrated
# 	 ANIMAL is a NOUN ← 's and the
# 	 ANIMAL is a NOUN ← in european NOUN , the ANIMAL symbolise the two NOUN of NOUN and timidity .
# 	 ANIMAL is a NOUN ← NOUN and
# 	 ANIMAL is a NOUN ← NOUN and ornamental vegetation provide ANIMAL
#
# ---------------------------------
#
# Pattern: * as
# # of hits:  0
# Hits:
# # of new finds:  15877
# Examples of new finds:
# 	 ANIMAL is a NOUN ← exploit NOUN NOUN to keep ANIMAL together on unfenced NOUN such as hill farming ,
# 	 ANIMAL is a NOUN ← NOUN ANIMAL and marine ANIMAL be commonly use in japanese NOUN ; food such as unadon
# 	 ANIMAL is a NOUN ← such as NOUN and other ANIMAL , have NOUN shape bony NOUN call odontoid process at the
# 	 ANIMAL is a NOUN ← the brown ANIMAL and both NOUN of black bear sometimes take large NOUN , such as deer and
# 	 ANIMAL is a NOUN ← the Middle Ages ; these ANIMAL be use as NOUN NOUN .
# 	 ANIMAL is a NOUN ← Most ANIMAL release their nitrogenous NOUN as NOUN .
# 	 ANIMAL is a NOUN ← excessive NOUN plume of male ANIMAL as
# 	 ANIMAL is a NOUN ← the ANIMAL have two NOUN which be associate with the branchial NOUN ; these and their associate
# 	 ANIMAL is a NOUN ← the IUCN list the asian ANIMAL as endanger due to the NOUN decline by NOUN over " the last three
# 	 ANIMAL is a NOUN ← in the 21st NOUN , ANIMAL may be take by NOUN NOUN as zebra skin rug sell
# 	 ANIMAL is a NOUN ← ANIMAL and the asian
# 	 ANIMAL is a NOUN ← ANIMAL appear in western popular NOUN as stereotype NOUN - NOUN and have feature in entertainment
# 	 ANIMAL is a NOUN ← in asian NOUN , while ANIMAL soup be
# 	 ANIMAL is a NOUN ← irish NOUN , NOUN associate ANIMAL with fairy and
# 	 ANIMAL is a NOUN ← in some NOUN , ANIMAL be use as NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL such as the Gila NOUN produce NOUN with medical NOUN .
# 	 ANIMAL is a NOUN ← and sustainable NOUN NOUN , ANIMAL be be cultivate by commercial NOUN operate grasshopper NOUN and be be use as
# 	 ANIMAL is a NOUN ← also use for some other ANIMAL - shaped NOUN , such as electric eel
# 	 ANIMAL is a NOUN ← tell that in Japan , ANIMAL be see as NOUN of the dead , condemn
# 	 ANIMAL is a NOUN ← be relatively poor ; the ANIMAL NOUN can not see as well
#
# ---------------------------------
#
# Pattern: , * ,
# # of hits:  0
# Hits:
# # of new finds:  2494
# Examples of new finds:
# 	 ANIMAL is a NOUN ← , such as the NOUN ANIMAL , the chinese NOUN silkmoth , the Assam silkmoth
# 	 ANIMAL is a NOUN ← , several NOUN of NOUN ANIMAL , include the Komodo
# 	 ANIMAL is a NOUN ← , NOUN likely do kill ANIMAL occasionally , and the large NOUN NOUN of savanna chimpanzee may have
# 	 ANIMAL is a NOUN ← , nor shall he use ANIMAL , NOUN , hey , harepipe nor
# 	 ANIMAL is a NOUN ← , have adapt to hunt ANIMAL , target NOUN , NOUN or even NOUN - adult .
# 	 ANIMAL is a NOUN ← , which can cause the ANIMAL to not receive adequate NOUN and water , cause serious
# 	 ANIMAL is a NOUN ← , only NOUN of the ANIMAL NOUN become gregarious , with scatter NOUN of hopper spread out over
# 	 ANIMAL is a NOUN ← , NOUN , NOUN and ANIMAL be now protect under strong NOUN welfare legislation in the UK
# 	 ANIMAL is a NOUN ← , NOUN ANIMAL , NOUN ANIMAL , NOUN beetle and true NOUN .
# 	 ANIMAL is a NOUN ← , these NOUN - like ANIMAL be nimble - bodied , wolfish NOUN ; one species among they
# 	 ANIMAL is a NOUN ← , -ae , also mean ANIMAL , possibly from NOUN and parere , refer to
# 	 ANIMAL is a NOUN ← , particularly the Albert 's ANIMAL , with the NOUN that little NOUN about its NOUN have be document .
# 	 ANIMAL is a NOUN ← , with domesticated and undomesticated ANIMAL be important NOUN of NOUN , meat , and feather
# 	 ANIMAL is a NOUN ← , Gifu Prefecture , where ANIMAL NOUN have continue uninterrupted for 1300 NOUN , or in the city
# 	 ANIMAL is a NOUN ← , the Netherlands , where ANIMAL have parent NOUN .
# 	 ANIMAL is a NOUN ← , NOUN ANIMAL , NOUN ANIMAL , NOUN bee , NOUN NOUN bee , NOUN bee , alkali bee and
# 	 ANIMAL is a NOUN ← , nor shall he use ANIMAL , NOUN , NOUN , NOUN nor cord , nor other
# 	 ANIMAL is a NOUN ← , may be harmful to ANIMAL , increase NOUN , damage NOUN , and cause NOUN sickness by force they to
# 	 ANIMAL is a NOUN ← , and the great white ANIMAL , have two to three NOUN or more , depend on
# 	 ANIMAL is a NOUN ← , unlike most NOUN , ANIMAL express NOUN as NOUN through most tissue , which
#
# ---------------------------------
#
# Pattern: ANIMAL , like * NOUN *
# # of hits:  0
# Hits:
# # of new finds:  69
# Examples of new finds:
# 	 ANIMAL is a NOUN ← ANIMAL , like most NOUN , be NOUN with four type of colour
# 	 ANIMAL is a NOUN ← ANIMAL , like NOUN , NOUN and other more popularly recognize
# 	 ANIMAL is a NOUN ← ANIMAL , like other NOUN , may symbolize NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL , like the NOUN ANIMAL , have negative NOUN , allow they to rest
# 	 ANIMAL is a NOUN ← ANIMAL , like other NOUN , display several NOUN that lead to very low
# 	 ANIMAL is a NOUN ← ANIMAL , like other NOUN , display several adaptation that
# 	 ANIMAL is a NOUN ← ANIMAL , like other NOUN , fly in a v
# 	 ANIMAL is a NOUN ← ANIMAL , like most NOUN , be NOUN with four NOUN of colour receptor in the
# 	 ANIMAL is a NOUN ← ANIMAL , like other NOUN , have a limit ability
# 	 ANIMAL is a NOUN ← ANIMAL , like many other NOUN of parrot , be able
# 	 ANIMAL is a NOUN ← ANIMAL , like most other NOUN , keep at least four
# 	 ANIMAL is a NOUN ← ANIMAL , like NOUN and NOUN , have blue blood due
# 	 ANIMAL is a NOUN ← ANIMAL , like other NOUN , possess a special upper NOUN in the back of the
# 	 ANIMAL is a NOUN ← ANIMAL , like many other NOUN of NOUN , be able to mimic
# 	 ANIMAL is a NOUN ← ANIMAL , like all NOUN , have jointed , or
# 	 ANIMAL is a NOUN ← ANIMAL , like many NOUN , exhibit NOUN NOUN NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL , like other NOUN NOUN but unlike more basal cephalopod
# 	 ANIMAL is a NOUN ← ANIMAL , like other NOUN , possess only one NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL , like many social NOUN , can mobilize the entire
# 	 ANIMAL is a NOUN ← ANIMAL , like many NOUN , exhibit NOUN NOUN fidelity .
#
# ---------------------------------
#
# Pattern: ANIMAL be * NOUN *
# # of hits:  0
# Hits:
# # of new finds:  5542
# Examples of new finds:
# 	 ANIMAL is a NOUN ← ANIMAL be an important NOUN of the global agricultural economy
# 	 ANIMAL is a NOUN ← ANIMAL be also mimic by NOUN such as the bee orchid
# 	 ANIMAL is a NOUN ← ANIMAL be a diverse NOUN of NOUN of the NOUN Dinosauria .
# 	 ANIMAL is a NOUN ← ANIMAL be highly social and most NOUN occur in group of up
# 	 ANIMAL is a NOUN ← ANIMAL be able to acquire orthographic NOUN NOUN , which form part of
# 	 ANIMAL is a NOUN ← ANIMAL be consume by NOUN in many different NOUN around the world .
# 	 ANIMAL is a NOUN ← ANIMAL be at their most vulnerable to NOUN when they be undergo metamorphosis
# 	 ANIMAL is a NOUN ← ANIMAL be more gear towards tactile NOUN NOUN than the plover , which
# 	 ANIMAL is a NOUN ← ANIMAL be usually small , measure between 4 and 15 NOUN in length .
# 	 ANIMAL is a NOUN ← ANIMAL be sometimes use as NOUN : the Onabasulu of Papua
# 	 ANIMAL is a NOUN ← ANIMAL be kill by NOUN for their NOUN , which be buy and
# 	 ANIMAL is a NOUN ← ANIMAL be a well - define NOUN , partly because of the
# 	 ANIMAL is a NOUN ← ANIMAL be commonly castrate adult NOUN NOUN , because NOUN inhibit testosterone and aggression ,
# 	 ANIMAL is a NOUN ← ANIMAL be the only live NOUN of the family Orycteropodidae and
# 	 ANIMAL is a NOUN ← ANIMAL be work NOUN especially suited to their NOUN habitat and be a vital
# 	 ANIMAL is a NOUN ← ANIMAL be the only live NOUN of the NOUN Orycteropodidae and the order Tubulidentata
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN in the NOUN Mephitidae .
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN who NOUN - feed on NOUN shrimp and blue - green
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN - breathe NOUN that have eight NOUN , chelicera with fang generally
# 	 ANIMAL is a NOUN ← ANIMAL be social NOUN that live in NOUN .
#
# ---------------------------------
#
# Pattern: ANIMAL be * NOUN * .
# # of hits:  0
# Hits:
# # of new finds:  5363
# Examples of new finds:
# 	 ANIMAL is a NOUN ← ANIMAL be widely distribute , range from the NOUN to subarctic region , but
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of NOUN of the NOUN Accipitridae .
# 	 ANIMAL is a NOUN ← ANIMAL be the dominant terrestrial NOUN of the Mesozoic Era ,
# 	 ANIMAL is a NOUN ← ANIMAL be often use in the NOUN of leprosy , since they
# 	 ANIMAL is a NOUN ← ANIMAL be social NOUN , often form NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL be sacred to the syrian NOUN Atargatis and , during her
# 	 ANIMAL is a NOUN ← ANIMAL be also excellent NOUN and NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL be a widely distribute and diverse NOUN of fully aquatic placental marine
# 	 ANIMAL is a NOUN ← ANIMAL be distribute into two evolutionarily independent NOUN within the suborder Hystricomorpha of
# 	 ANIMAL is a NOUN ← ANIMAL be an important NOUN species in Western Hemisphere ecosystem
# 	 ANIMAL is a NOUN ← ANIMAL be iconic and charismatic NOUN whose conservation be of global
# 	 ANIMAL is a NOUN ← ANIMAL be a NOUN of warm - blooded NOUN constitute the class ave )
# 	 ANIMAL is a NOUN ← ANIMAL be occasionally affect by a NOUN know as " NOUN penis " .
# 	 ANIMAL is a NOUN ← ANIMAL be typically NOUN - dwell NOUN with powerful hind leg which
# 	 ANIMAL is a NOUN ← ANIMAL be know to host a wide NOUN of NOUN , include tick , flea
# 	 ANIMAL is a NOUN ← ANIMAL be typically NOUN - dwell NOUN with powerful hind NOUN which allow they to escape
# 	 ANIMAL is a NOUN ← ANIMAL be omnivorous , eat both NOUN and NOUN material and change their diet
# 	 ANIMAL is a NOUN ← ANIMAL be playful NOUN and appear to engage in various NOUN for sheer enjoyment , such
# 	 ANIMAL is a NOUN ← ANIMAL be big than most Old World NOUN , which be their relative
# 	 ANIMAL is a NOUN ← ANIMAL be first import into the US in the late NOUN as zoo exhibit .
#
# ---------------------------------
#
# Pattern: ANIMAL be * NOUN * have
# # of hits:  0
# Hits:
# # of new finds:  233
# Examples of new finds:
# 	 ANIMAL is a NOUN ← ANIMAL be value as NOUN by NOUN and also have many cultural
# 	 ANIMAL is a NOUN ← ANIMAL be somewhat generalized NOUN lack special NOUN ; they have chew mouthpart
# 	 ANIMAL is a NOUN ← ANIMAL be opportunistically target by NOUN parasite , occasionally have egg
# 	 ANIMAL is a NOUN ← ANIMAL be distinct in their NOUN from other insect in have
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , and their NOUN NOUN have distinct loph between protocone
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , and their NOUN tooth have distinct loph between
# 	 ANIMAL is a NOUN ← ANIMAL be the peculiar creep ANIMAL in the NOUN Staurocladia and Eleutheria , which have NOUN disk from 0.5 millimetre to
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN - breathe NOUN that have eight NOUN , chelicera with fang generally
# 	 ANIMAL is a NOUN ← ANIMAL be gradually lose their third NOUN , with some NOUN have they congenitally absent .
# 	 ANIMAL is a NOUN ← ANIMAL be small , mostly carnivorous NOUN that have a wide distribution
# 	 ANIMAL is a NOUN ← ANIMAL be also dentally precocious at NOUN , and have their full
# 	 ANIMAL is a NOUN ← ANIMAL be inquisitive NOUN and have be know to approach NOUN if they see unexpected movement
# 	 ANIMAL is a NOUN ← ANIMAL be bear hairless and blind in a NOUN the mother will have prepare
# 	 ANIMAL is a NOUN ← ANIMAL be agile NOUN , while NOUN have a weak , fluttery
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN - breathe NOUN that have eight limb ,
# 	 ANIMAL is a NOUN ← ANIMAL be consume in many NOUN globally , but this NOUN have only become popular in
# 	 ANIMAL is a NOUN ← ANIMAL be ubiquitous in NOUN ; numerous NOUN have reference dinosaur in print
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of a NOUN of exotic NOUN that have be central to
# 	 ANIMAL is a NOUN ← ANIMAL be ancient australian NOUN : the Australian Museum have
# 	 ANIMAL is a NOUN ← ANIMAL be typically eat when NOUN be lean and tribal NOUN have not yet develop or
#
# ---------------------------------
#
# Pattern: ANIMAL be * NOUN * specie
# # of hits:  0
# Hits:
# # of new finds:  112
# Examples of new finds:
# 	 ANIMAL is a NOUN ← ANIMAL be the most widely eat NOUN , with about 344 specie
# 	 ANIMAL is a NOUN ← ANIMAL be a NOUN - dependent species , mean
# 	 ANIMAL is a NOUN ← ANIMAL be very sensitive to anthropogenic NOUN , and be keystone specie
# 	 ANIMAL is a NOUN ← ANIMAL be the swarm NOUN of certain specie of short
# 	 ANIMAL is a NOUN ← ANIMAL be unique among NOUN for their NOUN , which differ from species
# 	 ANIMAL is a NOUN ← ANIMAL be an important NOUN NOUN in Western Hemisphere NOUN , link numerous specie at
# 	 ANIMAL is a NOUN ← ANIMAL be among the large live NOUN NOUN , with live specie range
# 	 ANIMAL is a NOUN ← ANIMAL be specialized to feed on small NOUN , with each anteater species
# 	 ANIMAL is a NOUN ← ANIMAL be distinguish from live NOUN by their spirally twisted NOUN and in some later species
# 	 ANIMAL is a NOUN ← ANIMAL be divide into seven NOUN that contain a NOUN of about 20,000 specie .
# 	 ANIMAL is a NOUN ← ANIMAL be social NOUN ; a large NOUN of specie be either gregarious
# 	 ANIMAL is a NOUN ← ANIMAL be the fourth or fifth heavy live NOUN after the two specie of
# 	 ANIMAL is a NOUN ← ANIMAL be a common NOUN for two NOUN specie of the genus Pavo
# 	 ANIMAL is a NOUN ← ANIMAL be very sensitive to anthropogenic NOUN , and be NOUN specie , which can indicate
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN - NOUN , with a few specie
# 	 ANIMAL is a NOUN ← ANIMAL be a common NOUN for two bird specie of
# 	 ANIMAL is a NOUN ← ANIMAL be important as NOUN for some specie of plant
# 	 ANIMAL is a NOUN ← ANIMAL be represent on every NOUN by both extant specie and
# 	 ANIMAL is a NOUN ← ANIMAL be the primary NOUN for at least four specie
# 	 ANIMAL is a NOUN ← ANIMAL be a common NOUN for several specie of bird
#
# ---------------------------------
#
# Pattern: ANIMAL be NOUN *
# # of hits:  0
# Hits:
# # of new finds:  902
# Examples of new finds:
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , which mean that they
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN with a hard protective NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of habit that respond well
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of the primitive avialan which
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , and their NOUN NOUN have distinct loph between protocone
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of prey of the family
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN NOUN crustacean of the family Nephropidae
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , so environmental NOUN affect their NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of the superorder Dictyoptera ,
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN ; their diet consist mostly
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of the order Testudines ,
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , and their NOUN tooth have distinct loph between
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of NOUN trafficking where they be sell
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN - breathe NOUN that have eight NOUN , chelicera with fang generally
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN NOUN , wait for NOUN or land animal to come
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of several NOUN within the family Phasianidae in
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , feed on NOUN NOUN and bud , branch ,
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN - produce NOUN ; they do not need
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN feeder , draw water in
#
# ---------------------------------
#
# Pattern: ANIMAL be NOUN * .
# # of hits:  0
# Hits:
# # of new finds:  892
# Examples of new finds:
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , which mean that they undergo complete NOUN , with a series of
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN and typically eat live prey
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of habit that respond well
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of the primitive NOUN which first appear during the
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of the Sirenia order of
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of NOUN of the family Accipitridae .
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN NOUN NOUN of the family Nephropidae or
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of the Xenarthra superorder ,
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of the NOUN Dictyoptera , which include the
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN ; their NOUN consist mostly of grass ,
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN in the family Viperidae ,
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of the NOUN Testudines , characterize by a
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , and their NOUN NOUN have distinct NOUN between protocone , paracone ,
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of NOUN NOUN where they be sell as
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN and therefore , arthropod .
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN NOUN , wait for NOUN or NOUN animal to come close ,
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of a NOUN of exotic animal that have
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , feed on NOUN NOUN and NOUN , branch , grass ,
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN comprise the NOUN Papio , one of the
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN NOUN , so will naturally concentrate
#
# ---------------------------------
#
# Pattern: ANIMAL be NOUN * and
# # of hits:  0
# Hits:
# # of new finds:  231
# Examples of new finds:
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN who NOUN - feed on NOUN shrimp and blue - green
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN fermenter , and their digestive
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN for many NOUN - cause NOUN include NOUN , virus , and protozoan
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , feed on NOUN leave and bud , grass
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , but their NOUN primarily consist of earthworm and
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN of the NOUN Holometabola , and accordingly most
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , feed on NOUN NOUN and bud , branch ,
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN who NOUN - feed on NOUN NOUN and blue - green algae
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , feed on NOUN NOUN and bud , grass ,
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN NOUN , and their digestive NOUN can last 100 hour in
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , feed on NOUN leave and bud , branch
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , and their cheek tooth
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , and may mistake NOUN for large predator , follow
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , which mean they can eat NOUN and plant matter .
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN rather than NOUN NOUN , and in many case
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN NOUN and often eat their own NOUN to recover nutrient digest in
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , and their NOUN tooth have distinct loph between
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN rather than NOUN disperser , and in many
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN fermenter and often eat their
# 	 ANIMAL is a NOUN ← ANIMAL be NOUN , feed primarily on NOUN , and take any other
#
# ---------------------------------
#
# Pattern: ANIMAL be the * NOUN *
# # of hits:  0
# Hits:
# # of new finds:  309
# Examples of new finds:
# 	 ANIMAL is a NOUN ← ANIMAL be the small mature NOUN , measure 7.5–13   cm
# 	 ANIMAL is a NOUN ← ANIMAL be the four extant NOUN NOUN in the suborder Vermilingua ,
# 	 ANIMAL is a NOUN ← ANIMAL be the second - large live NOUN , after capybara , weigh
# 	 ANIMAL is a NOUN ← ANIMAL be the primary NOUN for at least four specie
# 	 ANIMAL is a NOUN ← ANIMAL be the common NOUN for any member of the
# 	 ANIMAL is a NOUN ← ANIMAL be the only NOUN that display true NOUN , use their neck and
# 	 ANIMAL is a NOUN ← ANIMAL be the most widely eat NOUN , with about 344 specie
# 	 ANIMAL is a NOUN ← ANIMAL be the large live terrestrial NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL be the four extant NOUN NOUN in the NOUN Vermilingua , commonly know for
# 	 ANIMAL is a NOUN ← ANIMAL be the only NOUN that migrate long distance ,
# 	 ANIMAL is a NOUN ← ANIMAL be the large live NOUN NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL be the common NOUN use for all squamate NOUN other than snake , encompass
# 	 ANIMAL is a NOUN ← ANIMAL be the principal sacrificial NOUN for the Huichal Indians of
# 	 ANIMAL is a NOUN ← ANIMAL be the swarm NOUN of certain specie of short
# 	 ANIMAL is a NOUN ← ANIMAL be the second - large live NOUN , after NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL be the only NOUN capable of sustained NOUN , as oppose to glide
# 	 ANIMAL is a NOUN ← ANIMAL be the only NOUN that lose all their NOUN in their first moult .
# 	 ANIMAL is a NOUN ← ANIMAL be the only " ANIMAL " NOUN that be not a member
# 	 ANIMAL is a NOUN ← ANIMAL be the fourth or fifth heavy live NOUN after the two specie of
# 	 ANIMAL is a NOUN ← ANIMAL be the second large NOUN of pollinator after the Hymenoptera
#
# ---------------------------------
#
# Pattern: ANIMAL be the * NOUN * specie
# # of hits:  0
# Hits:
# # of new finds:  28
# Examples of new finds:
# 	 ANIMAL is a NOUN ← ANIMAL be the fourth or fifth heavy live NOUN after the two specie of
# 	 ANIMAL is a NOUN ← ANIMAL be the swarm NOUN of certain specie of short
# 	 ANIMAL is a NOUN ← ANIMAL be the primary NOUN for at least four specie
# 	 ANIMAL is a NOUN ← ANIMAL be the most widely eat NOUN , with about 344 specie
#
# ---------------------------------
#
# Pattern: ANIMAL be the * NOUN .
# # of hits:  0
# Hits:
# # of new finds:  309
# Examples of new finds:
# 	 ANIMAL is a NOUN ← ANIMAL be the small mature NOUN , measure 7.5–13   cm
# 	 ANIMAL is a NOUN ← ANIMAL be the four extant NOUN NOUN in the suborder Vermilingua ,
# 	 ANIMAL is a NOUN ← ANIMAL be the second - large live NOUN , after capybara , weigh
# 	 ANIMAL is a NOUN ← ANIMAL be the primary NOUN for at least four specie
# 	 ANIMAL is a NOUN ← ANIMAL be the common NOUN for any member of the
# 	 ANIMAL is a NOUN ← ANIMAL be the only NOUN that display true NOUN , use their neck and
# 	 ANIMAL is a NOUN ← ANIMAL be the most widely eat NOUN , with about 344 specie
# 	 ANIMAL is a NOUN ← ANIMAL be the large live terrestrial NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL be the four extant NOUN NOUN in the NOUN Vermilingua , commonly know for
# 	 ANIMAL is a NOUN ← ANIMAL be the only NOUN that migrate long distance ,
# 	 ANIMAL is a NOUN ← ANIMAL be the large live NOUN NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL be the common NOUN use for all squamate NOUN other than snake , encompass
# 	 ANIMAL is a NOUN ← ANIMAL be the principal sacrificial NOUN for the Huichal Indians of
# 	 ANIMAL is a NOUN ← ANIMAL be the swarm NOUN of certain specie of short
# 	 ANIMAL is a NOUN ← ANIMAL be the second - large live NOUN , after NOUN .
# 	 ANIMAL is a NOUN ← ANIMAL be the only NOUN capable of sustained NOUN , as oppose to glide
# 	 ANIMAL is a NOUN ← ANIMAL be the only NOUN that lose all their NOUN in their first moult .
# 	 ANIMAL is a NOUN ← ANIMAL be the only " ANIMAL " NOUN that be not a member
# 	 ANIMAL is a NOUN ← ANIMAL be the fourth or fifth heavy live NOUN after the two specie of
# 	 ANIMAL is a NOUN ← ANIMAL be the second large NOUN of pollinator after the Hymenoptera
#
# ---------------------------------
#
# Pattern: be
# # of hits:  0
# Hits:
# # of new finds:  5320
# Examples of new finds:
# 	 ANIMAL is a NOUN ← be reportedly observe prey
# 	 ANIMAL is a NOUN ← be the
# 	 ANIMAL is a NOUN ← be a
# 	 ANIMAL is a NOUN ← be a simplified NOUN of ANIMAL NOUN base on their evolutionary NOUN , and those of the
# 	 ANIMAL is a NOUN ← because ANIMAL ' NOUN be quite soft , the
# 	 ANIMAL is a NOUN ← be
# 	 ANIMAL is a NOUN ← between
# 	 ANIMAL is a NOUN ← be palatable , whereas old ANIMAL catch after a lengthy NOUN be inedible .
# 	 ANIMAL is a NOUN ← because NOUN NOUN of male ANIMAL require complex aerial NOUN .
# 	 ANIMAL is a NOUN ← be often show
# 	 ANIMAL is a NOUN ← be modify into NOUN , ANIMAL can travel at NOUN of up to 20 NOUN , though they be not
# 	 ANIMAL is a NOUN ← be use by NOUN - ANIMAL at least 2.5
# 	 ANIMAL is a NOUN ← be a NOUN around , ANIMAL be not
# 	 ANIMAL is a NOUN ← between a leopard and a
# 	 ANIMAL is a NOUN ← between the NOUN and the ANIMAL include a similar NOUN – both use a pacing
# 	 ANIMAL is a NOUN ← between indian ANIMAL and green
# 	 ANIMAL is a NOUN ← be a fertile NOUN for ANIMAL , with a
# 	 ANIMAL is a NOUN ← be popularly depict as an ANIMAL - head NOUN in the act of write
# 	 ANIMAL is a NOUN ← be a fertile NOUN for ANIMAL , with a mild NOUN , less snow , and
# 	 ANIMAL is a NOUN ← be not always associate with ANIMAL NOUN toward open water .
#
# ---------------------------------
#
# Pattern: be *
# # of hits:  0
# Hits:
# # of new finds:  4396
# Examples of new finds:
# 	 ANIMAL is a NOUN ← be the blue or indian
# 	 ANIMAL is a NOUN ← be accomplish by throw the ANIMAL to the NOUN and lash all four foot
# 	 ANIMAL is a NOUN ← be often call " NOUN ANIMAL " regardless of height
# 	 ANIMAL is a NOUN ← be find in
# 	 ANIMAL is a NOUN ← be write about one such ANIMAL NOUN in the New York Zoo
# 	 ANIMAL is a NOUN ← be individually learn
# 	 ANIMAL is a NOUN ← be termitophile and
# 	 ANIMAL is a NOUN ← be use by the
# 	 ANIMAL is a NOUN ← be a long NOUN of ANIMAL meat consumption in
# 	 ANIMAL is a NOUN ← be relatively little NOUN between ANIMAL geographical population ,
# 	 ANIMAL is a NOUN ← be generally accept that the ANIMAL NOUN be most closely relate to the NOUN - bird and some authority
# 	 ANIMAL is a NOUN ← be popularly depict as an ANIMAL - head NOUN in the act of write
# 	 ANIMAL is a NOUN ← be not
# 	 ANIMAL is a NOUN ← be some NOUN of solitary ANIMAL that build
# 	 ANIMAL is a NOUN ← be a dual - NOUN ANIMAL common in Africa and Asia with large NOUN of NOUN within and around its tail
# 	 ANIMAL is a NOUN ← be some NOUN of solitary ANIMAL that build communal NOUN , each insect have its
# 	 ANIMAL is a NOUN ← be show more in tundra
# 	 ANIMAL is a NOUN ← be vulnerability to predator
# 	 ANIMAL is a NOUN ← be also the NOUN - ANIMAL , another NOUN of macropod , which inhabit
# 	 ANIMAL is a NOUN ← be the NOUN of NOUN ANIMAL NOUN to remove the dead NOUN from wound , most commonly
#
# ---------------------------------
#
# Pattern: like most NOUN , * ANIMAL have a
# # of hits:  0
# Hits:
# # of new finds:  15
# Examples of new finds:
# 	 ANIMAL is a NOUN ← like most NOUN , an ANIMAL have a
# 	 ANIMAL is a NOUN ← like most NOUN , an ANIMAL have a three - chambered NOUN with two atrium , one
# 	 ANIMAL is a NOUN ← like most NOUN , an ANIMAL have a three - chambered NOUN with two NOUN , one ventricle , and
# 	 ANIMAL is a NOUN ← like most NOUN , female ANIMAL have a
# 	 ANIMAL is a NOUN ← like most NOUN , female ANIMAL have a NOUN call a marsupium in which
# 	 ANIMAL is a NOUN ← like most NOUN , female ANIMAL have a NOUN call a NOUN in which joey complete postnatal
# 	 ANIMAL is a NOUN ← like most NOUN , female ANIMAL have a NOUN call a NOUN in which NOUN complete postnatal development .
#
# ---------------------------------
#
# Pattern: like most NOUN , ANIMAL * ,
# # of hits:  0
# Hits:
# # of new finds:  18
# Examples of new finds:
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL inhale air ,
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL inhale NOUN , for the oxygen it
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL inhale NOUN , for the NOUN it contain , and exhale
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL can lose their NOUN in defence , a process
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL can lose their NOUN in NOUN , a process call autotomy
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL can lose their NOUN in NOUN , a NOUN call autotomy ; the predator
#
# ---------------------------------
#
# Pattern: like most NOUN , ANIMAL * the
# # of hits:  0
# Hits:
# # of new finds:  35
# Examples of new finds:
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL lack NOUN and NOUN sensor and rely on their
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL lack NOUN and NOUN NOUN and rely on their eye
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL lack NOUN and NOUN NOUN and rely on their NOUN to tell they which way
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL inhale NOUN , for the oxygen it
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL inhale NOUN , for the NOUN it contain , and exhale
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL can lose their
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL can lose their NOUN in defence , a process
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL can lose their NOUN in NOUN , a process call autotomy
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL can lose their NOUN in NOUN , a NOUN call autotomy ; the predator
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL migrate in the
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL migrate in the NOUN and the spring .
# 	 ANIMAL is a NOUN ← like most NOUN , ANIMAL migrate in the NOUN and the NOUN .
#
# ---------------------------------
#
# Pattern: like other NOUN , * ANIMAL *
# # of hits:  0
# Hits:
# # of new finds:  24
# Examples of new finds:
# 	 ANIMAL is a NOUN ← like other NOUN , the ANIMAL have a
# 	 ANIMAL is a NOUN ← like other NOUN , the ANIMAL have a NOUN of electrolocation , which it
# 	 ANIMAL is a NOUN ← like other NOUN , the ANIMAL have a NOUN of NOUN , which it use to
# 	 ANIMAL is a NOUN ← like other NOUN , an ANIMAL be bilaterally
# 	 ANIMAL is a NOUN ← like other NOUN , an ANIMAL be bilaterally symmetric with two NOUN and a beaked mouth at
# 	 ANIMAL is a NOUN ← like other NOUN , an ANIMAL be bilaterally symmetric with two NOUN and a beaked NOUN at the centre point of
# 	 ANIMAL is a NOUN ← like other NOUN , the ANIMAL 's eye
# 	 ANIMAL is a NOUN ← like other NOUN , the ANIMAL 's NOUN be compose of two type
# 	 ANIMAL is a NOUN ← like other NOUN , the ANIMAL 's NOUN be compose of two NOUN of cone cell compare to
# 	 ANIMAL is a NOUN ← like other NOUN , the ANIMAL 's NOUN be compose of two NOUN of NOUN cell compare to the human
# 	 ANIMAL is a NOUN ← like other NOUN , the ANIMAL 's NOUN be compose of two NOUN of NOUN NOUN compare to the human 's
#
# ---------------------------------
#
# Pattern: like other NOUN , ANIMAL *
# # of hits:  0
# Hits:
# # of new finds:  147
# Examples of new finds:
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL suffer from NOUN .
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL suffer from parasitism
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL have NOUN that detect NOUN and NOUN , and mechanoreceptor that respond
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL be ectothermic , produce very little metabolic NOUN .
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL have an open
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL have to molt
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL search for NOUN can break into NOUN house to feed on chicken
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL search for NOUN can break into poultry house
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL be ectothermic ,
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL groom socially to
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL have chemoreceptor that
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL will sometimes favour
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL search for food
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL have open circulatory
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL breathe through a NOUN of NOUN call NOUN which be attach to opening
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL be coelomate in
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL have NOUN that detect NOUN and NOUN , and NOUN that respond to touch .
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL extract NOUN from NOUN as it pass over their
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL originally evolve in
# 	 ANIMAL is a NOUN ← like other NOUN , ANIMAL have a three
#
# ---------------------------------
#
# Pattern: other
# # of hits:  0
# Hits:
# # of new finds:  675
# Examples of new finds:
# 	 ANIMAL is a NOUN ← other NOUN , the male ANIMAL have
# 	 ANIMAL is a NOUN ← other NOUN involve ANIMAL use their NOUN NOUN NOUN against an enemy .
# 	 ANIMAL is a NOUN ← other ANIMAL : the spectral ANIMAL , and the NOUN bat .
# 	 ANIMAL is a NOUN ← other ANIMAL begin their NOUN as NOUN lay in NOUN in water , or lay
# 	 ANIMAL is a NOUN ← other NOUN NOUN for banded ANIMAL include an
# 	 ANIMAL is a NOUN ← other NOUN that affect ANIMAL include Toxoplasma gondii , NOUN , and NOUN .
# 	 ANIMAL is a NOUN ← other NOUN include ANIMAL as social NOUN .
# 	 ANIMAL is a NOUN ← other very small ANIMAL , which have NOUN about one millimeter , be
# 	 ANIMAL is a NOUN ← other NOUN produce by ANIMAL include NOUN and " squeak - NOUN sound " .
# 	 ANIMAL is a NOUN ← other
# 	 ANIMAL is a NOUN ← other taxon
# 	 ANIMAL is a NOUN ← other ANIMAL commonly keep as NOUN be the three specie in
# 	 ANIMAL is a NOUN ← other communal ANIMAL include several Philoponella NOUN , Agelena consociata and Mallos
# 	 ANIMAL is a NOUN ← other than they be to ANIMAL and the NOUN of the three NOUN take NOUN in the Paleozoic or early
# 	 ANIMAL is a NOUN ← other modern NOUN for plan ANIMAL NOUN include GPS , GIS NOUN , and NOUN NOUN with rapid computer datum management
# 	 ANIMAL is a NOUN ← other ANIMAL will respond to the NOUN , and within a short
# 	 ANIMAL is a NOUN ← other ANIMAL may fight over the NOUN box , attack each other
# 	 ANIMAL is a NOUN ← other NOUN that affect ANIMAL be protozoan
# 	 ANIMAL is a NOUN ← other NOUN of ANIMAL be among the most common and important jellyfish NOUN .
# 	 ANIMAL is a NOUN ← other ANIMAL NOUN be find around the NOUN .
#
# ---------------------------------
#
# Pattern: the
# # of hits:  0
# Hits:
# # of new finds:  20162
# Examples of new finds:
# 	 ANIMAL is a NOUN ← the NOUN of the trap ANIMAL can
# 	 ANIMAL is a NOUN ← the Javan ANIMAL be one of the most endangered large NOUN in the world .
# 	 ANIMAL is a NOUN ← the NOUN be release from ANIMAL NOUN by NOUN right activist , or otherwise
# 	 ANIMAL is a NOUN ← the most important NOUN of ANIMAL NOUN be the remedial hunting of
# 	 ANIMAL is a NOUN ← the NOUN of rear ANIMAL for NOUN be know as heliciculture .
# 	 ANIMAL is a NOUN ← they emerge as
# 	 ANIMAL is a NOUN ← the NOUN , or less ANIMAL ; and the NOUN , or great ape .
# 	 ANIMAL is a NOUN ← the eastern white - bearded ANIMAL have see a steep NOUN .
# 	 ANIMAL is a NOUN ← the ANIMAL adopt the NOUN into his NOUN , and retain they after
# 	 ANIMAL is a NOUN ← the main NOUN NOUN , ANIMAL NOUN , and price into the
# 	 ANIMAL is a NOUN ← the old preserve NOUN of ANIMAL can be find
# 	 ANIMAL is a NOUN ← the ANIMAL be an important NOUN species for Africa 's large
# 	 ANIMAL is a NOUN ← the NOUN ' ANIMAL ' and ' NOUN ' be not precise ,
# 	 ANIMAL is a NOUN ← the NOUN , wear a ANIMAL NOUN be regard as NOUN NOUN among NOUN NOUN .
# 	 ANIMAL is a NOUN ← the chief NOUN of ANIMAL be for human NOUN , but fish meal be
# 	 ANIMAL is a NOUN ← the neural NOUN from seven ANIMAL yield an average NOUN NOUN NOUN of 80 NOUN , whereas a single grasshopper
# 	 ANIMAL is a NOUN ← the palatable yellow - eyed ANIMAL closely resemble the toxic California NOUN and the rough - skinned
# 	 ANIMAL is a NOUN ← the NOUN NOUN for adult ANIMAL can reach
# 	 ANIMAL is a NOUN ← the ANIMAL be distribute from the tropical NOUN in Mexico through Central America
# 	 ANIMAL is a NOUN ← the east asian ANIMAL NOUN confine themselves mostly to the NOUN of Russia , with much
#
# ---------------------------------
#
# Pattern: the ANIMAL be a * NOUN *
# # of hits:  0
# Hits:
# # of new finds:  496
# Examples of new finds:
# 	 ANIMAL is a NOUN ← the ANIMAL be a large and diverse NOUN with over 1,900 live specie
# 	 ANIMAL is a NOUN ← the ANIMAL be a solitary and territorial NOUN .
# 	 ANIMAL is a NOUN ← the ANIMAL be a long - range NOUN and individual disperse over distance
# 	 ANIMAL is a NOUN ← the ANIMAL be a very small NOUN .
# 	 ANIMAL is a NOUN ← the ANIMAL be a NOUN and be exceed in NOUN among land animal only by
# 	 ANIMAL is a NOUN ← the ANIMAL be a large pinniped marine NOUN with   discontinuous distribution
# 	 ANIMAL is a NOUN ← the ANIMAL be a widespread NOUN with a cosmopolitan NOUN .
# 	 ANIMAL is a NOUN ← the ANIMAL be a domestic NOUN that likely travel a commensal
# 	 ANIMAL is a NOUN ← the ANIMAL be a vocal NOUN with a broad NOUN of NOUN and sound ; the acoustic
# 	 ANIMAL is a NOUN ← the ANIMAL be a frequently use NOUN in heraldry , most commonly
# 	 ANIMAL is a NOUN ← the ANIMAL be a NOUN and an NOUN NOUN feed mainly on large and
# 	 ANIMAL is a NOUN ← the ANIMAL be a tropical NOUN NOUN of the NOUN Procyonidae relate to olingo ,
# 	 ANIMAL is a NOUN ← the ANIMAL be a recognisable NOUN of Australia .
# 	 ANIMAL is a NOUN ← the ANIMAL be a vocal NOUN with a broad NOUN of call and sound ;
# 	 ANIMAL is a NOUN ← the ANIMAL be a national NOUN of Papua New Guinea ,
# 	 ANIMAL is a NOUN ← the ANIMAL be a common NOUN in the mythology and cosmology
# 	 ANIMAL is a NOUN ← the ANIMAL be a NOUN of nine NOUN of NOUN in the genus Numenius ,
# 	 ANIMAL is a NOUN ← the ANIMAL be a domesticate NOUN of the gray NOUN .
# 	 ANIMAL is a NOUN ← the ANIMAL be a cosmopolitan paraphyletic NOUN of NOUN of thousand of specie ,
# 	 ANIMAL is a NOUN ← the ANIMAL be a NOUN of the NOUN Corvidae in the passerine order
#
# ---------------------------------
#
# Pattern: the ANIMAL be a * NOUN .
# # of hits:  0
# Hits:
# # of new finds:  496
# Examples of new finds:
# 	 ANIMAL is a NOUN ← the ANIMAL be a large and diverse NOUN with over 1,900 live specie
# 	 ANIMAL is a NOUN ← the ANIMAL be a solitary and territorial NOUN .
# 	 ANIMAL is a NOUN ← the ANIMAL be a long - range NOUN and individual disperse over distance
# 	 ANIMAL is a NOUN ← the ANIMAL be a very small NOUN .
# 	 ANIMAL is a NOUN ← the ANIMAL be a NOUN and be exceed in NOUN among land animal only by
# 	 ANIMAL is a NOUN ← the ANIMAL be a large pinniped marine NOUN with   discontinuous distribution
# 	 ANIMAL is a NOUN ← the ANIMAL be a widespread NOUN with a cosmopolitan NOUN .
# 	 ANIMAL is a NOUN ← the ANIMAL be a domestic NOUN that likely travel a commensal
# 	 ANIMAL is a NOUN ← the ANIMAL be a vocal NOUN with a broad NOUN of NOUN and sound ; the acoustic
# 	 ANIMAL is a NOUN ← the ANIMAL be a frequently use NOUN in heraldry , most commonly
# 	 ANIMAL is a NOUN ← the ANIMAL be a NOUN and an NOUN NOUN feed mainly on large and
# 	 ANIMAL is a NOUN ← the ANIMAL be a tropical NOUN NOUN of the NOUN Procyonidae relate to olingo ,
# 	 ANIMAL is a NOUN ← the ANIMAL be a recognisable NOUN of Australia .
# 	 ANIMAL is a NOUN ← the ANIMAL be a vocal NOUN with a broad NOUN of call and sound ;
# 	 ANIMAL is a NOUN ← the ANIMAL be a national NOUN of Papua New Guinea ,
# 	 ANIMAL is a NOUN ← the ANIMAL be a common NOUN in the mythology and cosmology
# 	 ANIMAL is a NOUN ← the ANIMAL be a NOUN of nine NOUN of NOUN in the genus Numenius ,
# 	 ANIMAL is a NOUN ← the ANIMAL be a domesticate NOUN of the gray NOUN .
# 	 ANIMAL is a NOUN ← the ANIMAL be a cosmopolitan paraphyletic NOUN of NOUN of thousand of specie ,
# 	 ANIMAL is a NOUN ← the ANIMAL be a NOUN of the NOUN Corvidae in the passerine order
#
# ---------------------------------
#
# Pattern: unlike other NOUN , * ANIMAL have a
# # of hits:  0
# Hits:
# # of new finds:  8
# Examples of new finds:
# 	 ANIMAL is a NOUN ← unlike other NOUN , a ANIMAL have a
# 	 ANIMAL is a NOUN ← unlike other NOUN , a ANIMAL have a cerebral NOUN and a four - chambered
# 	 ANIMAL is a NOUN ← unlike other NOUN , a ANIMAL have a cerebral NOUN and a four - chambered NOUN .
#
# ---------------------------------
#
# Pattern: unlike other NOUN , ANIMAL *
# # of hits:  0
# Hits:
# # of new finds:  17
# Examples of new finds:
# 	 ANIMAL is a NOUN ← unlike other NOUN , ANIMAL gill slit be
# 	 ANIMAL is a NOUN ← unlike other NOUN , ANIMAL NOUN slit be not cover ,
# 	 ANIMAL is a NOUN ← unlike other NOUN , ANIMAL NOUN NOUN be not cover , but
# 	 ANIMAL is a NOUN ← unlike other NOUN , ANIMAL ' red blood
# 	 ANIMAL is a NOUN ← unlike other NOUN , ANIMAL ' red NOUN cell be oval rather than
# 	 ANIMAL is a NOUN ← unlike other NOUN , ANIMAL ' red NOUN NOUN be oval rather than circular
#
# ---------------------------------
#
# Pattern: unlike other NOUN , ANIMAL * be
# # of hits:  0
# Hits:
# # of new finds:  15
# Examples of new finds:
# 	 ANIMAL is a NOUN ← unlike other NOUN , ANIMAL gill slit be
# 	 ANIMAL is a NOUN ← unlike other NOUN , ANIMAL NOUN slit be not cover ,
# 	 ANIMAL is a NOUN ← unlike other NOUN , ANIMAL NOUN NOUN be not cover , but
# 	 ANIMAL is a NOUN ← unlike other NOUN , ANIMAL ' red NOUN cell be oval rather than
# 	 ANIMAL is a NOUN ← unlike other NOUN , ANIMAL ' red NOUN NOUN be oval rather than circular
#
# ---------------------------------

# %% [markdown]
# ### To-Do

# %% [markdown]
# > 💡 **Consider**: when inspecting the new finds of each pattern, what do you notice? What patterns are productive, but imprecise? What patterns are precise, but unproductive?

# %% [markdown]
# **Response**: a pattern like "* and" is productive but imprecise while "unlike other NOUN , ANIMAL *" is precise but unproductive. Essentially if a pattern is too generic it captures a lot of relations but they are not as precise.

# %% [markdown]
# > 💡 **Consider**: Is there a better way than string/phrase matching to capture patterns such as "*This animal preserve includes __mammals__ such as __lions__, __elephants__, and __giraffes__*"? (This [paper](https://papers.nips.cc/paper_files/paper/2004/hash/358aee4cc897452c00244351e4d91f69-Abstract.html) may contain clues.)

# %% [markdown]
# **Response**: Instead of a rule based approach, a supervised learning approach as mentioned in the paper, which picks noun pairs from corpora and hypernym pairs from WordNet. Using hte sentences which have those nouns a model can be trained with manually designed features.

# %% [markdown]
# > 💡 **Consider**: You realize that there are some sentences in the zoologists' notes that are completely missed by your pipeline, such as the second sentence here: "*__Giraffes__ are tall. They are __mammals__.*" What are some ways you might improve your current approach or dataset?

# %% [markdown]
# **Response**: Including period and accepting a higher number of tokens between noun phrases can help with this.

# %% [markdown]
# > 💡 **Consider**: How might you extract not just ANIMAL → NOUN relations (e.g. "kangaroo" → "marsupial", "kangaroo" → "macropod"), but also NOUN → NOUN relations (e.g. "macropod" → "marsupial") to create a full taxonomy tree?

# %% [markdown]
# **Response**: Instead of just two labels (ANIMAL and NOUN), we can have 3 labels to track, macropod to marsupial relationships

# %% [markdown]
# # Submission

# %% [markdown]
# Congratulations on finishing HW5! Please ensure that you submit this completed notebook onto Gradescope. Make sure all cells in the notebook are run so that print statements are visible.
#
# `File` --> `Download` --> `Download .ipynb`
#
# Make sure your notebook is named `HW5.ipynb` when you upload it to [Gradescope](https://www.gradescope.com/courses/1238346) before April 6, 2026 at 11:59pm.

# %% [markdown]
# ## Addendum
#
# The list of animals in this homework are drawn from [Wikipedia's list of animal names](https://en.wikipedia.org/wiki/List_of_animal_names), and the zoologists' notes are actually sentences pulled from Wikipedia.
